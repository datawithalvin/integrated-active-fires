# %%
import polars as pl
import pandas as pd
from src.procedures import fetch_last_data
from dotenv import dotenv_values
import datetime
from sqlalchemy import create_engine

import geopandas as gpd
from shapely.geometry import Point

config = dotenv_values("../.env")

# %%
hist_2023 = pd.read_csv("../data/viirs-yearly-summary/viirs-snpp_2023.csv")

file_path = "../data/IndonesianCitiesDistrictsUpdated.json"
adm_df = gpd.read_file(file_path)

display(hist_2023.head(3), adm_df.head(3))
# Out:
#    latitude  longitude  brightness  scan  track  acq_date  acq_time satellite  \
# 0   0.45100  109.06416      334.46  0.42   0.38  1/1/2023       559         N
# 1  -1.32986  113.40453      342.43  0.41   0.37  1/1/2023       559         N
# 2  -0.84505  116.93285      341.42  0.41   0.45  1/1/2023       559         N
#
#   instrument confidence version  bright_t31    frp daynight
# 0      VIIRS          n  2.0NRT      288.34  27.04        D
# 1      VIIRS          n  2.0NRT      279.44   7.98        D
# 2      VIIRS          n  2.0NRT      286.10   9.12        D
#                 id provinsi                                           geometry
# 0       Aceh Barat     Aceh  POLYGON ((96.49109 4.62277, 96.49329 4.56110, ...
# 1  Aceh Barat Daya     Aceh  POLYGON ((97.15358 3.74559, 97.14205 3.73411, ...
# 2       Aceh Besar     Aceh  MULTIPOLYGON (((95.17371 5.55513, 95.15416 5.5...

# %%
# change datetype format
hist_2023["acq_date"] = pd.to_datetime(hist_2023["acq_date"]).dt.strftime('%Y-%m-%d')

# replave values
hist_2023["confidence"] = hist_2023["confidence"].replace({
    "n":"Nominal", "h":"High", "l":"Low"
})

hist_2023["daynight"] = hist_2023["daynight"].replace({
    "D":"Day", "N":"Night"
})


hist_2023.head(3)
# Out:
#    latitude  longitude  brightness  scan  track    acq_date  acq_time  \
# 0   0.45100  109.06416      334.46  0.42   0.38  2023-01-01       559
# 1  -1.32986  113.40453      342.43  0.41   0.37  2023-01-01       559
# 2  -0.84505  116.93285      341.42  0.41   0.45  2023-01-01       559
#
#   satellite instrument confidence version  bright_t31    frp daynight
# 0         N      VIIRS    Nominal  2.0NRT      288.34  27.04      Day
# 1         N      VIIRS    Nominal  2.0NRT      279.44   7.98      Day
# 2         N      VIIRS    Nominal  2.0NRT      286.10   9.12      Day

# %%
# Zip lat-lon as tuple, convert to Points object
hist_2023["coords"] = list(zip(hist_2023["longitude"], hist_2023["latitude"]))
hist_2023["coords"] = hist_2023["coords"].apply(Point)

# Turn into geodataframe, perform spatial join
points = gpd.GeoDataFrame(hist_2023, geometry="coords")
joined_df = gpd.tools.sjoin(points, adm_df, predicate="within", how='left')

joined_df.head(3)
# Out:
# C:\Users\PF2L6BL6\AppData\Local\Temp\ipykernel_18584\2749868562.py:7: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   joined_df = gpd.tools.sjoin(points, adm_df, predicate="within", how='left')
#    latitude  longitude  brightness  scan  track    acq_date  acq_time  \
# 0   0.45100  109.06416      334.46  0.42   0.38  2023-01-01       559
# 1  -1.32986  113.40453      342.43  0.41   0.37  2023-01-01       559
# 2  -0.84505  116.93285      341.42  0.41   0.45  2023-01-01       559
#
#   satellite instrument confidence version  bright_t31    frp daynight  \
# 0         N      VIIRS    Nominal  2.0NRT      288.34  27.04      Day
# 1         N      VIIRS    Nominal  2.0NRT      279.44   7.98      Day
# 2         N      VIIRS    Nominal  2.0NRT      286.10   9.12      Day
#
#                        coords  index_right                 id  \
# 0   POINT (109.06416 0.45100)        337.0           Mempawah
# 1  POINT (113.40453 -1.32986)        111.0         Gunung Mas
# 2  POINT (116.93285 -0.84505)        279.0  Kutai Kartanegara
#
#             provinsi
# 0   Kalimantan Barat
# 1  Kalimantan Tengah
# 2   Kalimantan Timur

# %%
# Rename some columns, drop the unnecessary ones for the analysis
joined_df = joined_df.rename(columns={
    "id":"second_adm", "provinsi":"first_adm"
})

joined_df = joined_df.drop(["scan", "track", "bright_t31", "coords", "index_right"], axis=1)

joined_df.head()
# Out:
#    latitude  longitude  brightness    acq_date  acq_time satellite instrument  \
# 0   0.45100  109.06416      334.46  2023-01-01       559         N      VIIRS
# 1  -1.32986  113.40453      342.43  2023-01-01       559         N      VIIRS
# 2  -0.84505  116.93285      341.42  2023-01-01       559         N      VIIRS
# 3  -1.47823  113.02875      329.07  2023-01-01       559         N      VIIRS
# 4  -1.43891  114.12376      327.32  2023-01-01       559         N      VIIRS
#
#   confidence version    frp daynight         second_adm          first_adm
# 0    Nominal  2.0NRT  27.04      Day           Mempawah   Kalimantan Barat
# 1    Nominal  2.0NRT   7.98      Day         Gunung Mas  Kalimantan Tengah
# 2    Nominal  2.0NRT   9.12      Day  Kutai Kartanegara   Kalimantan Timur
# 3    Nominal  2.0NRT   2.06      Day           Katingan  Kalimantan Tengah
# 4    Nominal  2.0NRT   2.43      Day             Kapuas  Kalimantan Tengah

# %%
pl_joined_df = pl.from_pandas(joined_df)
pl_joined_df = pl_joined_df.with_columns(
    pl.col("acq_date").str.strptime(pl.Date, "%Y-%m-%d")
)

pl_joined_df.head(3)
# Out:
# shape: (3, 13)
# ┌──────────┬───────────┬────────────┬────────────┬───┬───────┬──────────┬─────────────┬────────────┐
# │ latitude ┆ longitude ┆ brightness ┆ acq_date   ┆ … ┆ frp   ┆ daynight ┆ second_adm  ┆ first_adm  │
# │ ---      ┆ ---       ┆ ---        ┆ ---        ┆   ┆ ---   ┆ ---      ┆ ---         ┆ ---        │
# │ f64      ┆ f64       ┆ f64        ┆ date       ┆   ┆ f64   ┆ str      ┆ str         ┆ str        │
# ╞══════════╪═══════════╪════════════╪════════════╪═══╪═══════╪══════════╪═════════════╪════════════╡
# │ 0.451    ┆ 109.06416 ┆ 334.46     ┆ 2023-01-01 ┆ … ┆ 27.04 ┆ Day      ┆ Mempawah    ┆ Kalimantan │
# │          ┆           ┆            ┆            ┆   ┆       ┆          ┆             ┆ Barat      │
# │ -1.32986 ┆ 113.40453 ┆ 342.43     ┆ 2023-01-01 ┆ … ┆ 7.98  ┆ Day      ┆ Gunung Mas  ┆ Kalimantan │
# │          ┆           ┆            ┆            ┆   ┆       ┆          ┆             ┆ Tengah     │
# │ -0.84505 ┆ 116.93285 ┆ 341.42     ┆ 2023-01-01 ┆ … ┆ 9.12  ┆ Day      ┆ Kutai       ┆ Kalimantan │
# │          ┆           ┆            ┆            ┆   ┆       ┆          ┆ Kartanegara ┆ Timur      │
# └──────────┴───────────┴────────────┴────────────┴───┴───────┴──────────┴─────────────┴────────────┘

# %%
connection = config.get("CONNECTION_URI")

# write to database
pl_joined_df.write_database(table_name="processed_viirs",  connection=connection, if_exists="append")

# %%
pl_joined_df
# Out:
# shape: (83_284, 13)
# ┌──────────┬───────────┬────────────┬────────────┬───┬───────┬──────────┬─────────────┬────────────┐
# │ latitude ┆ longitude ┆ brightness ┆ acq_date   ┆ … ┆ frp   ┆ daynight ┆ second_adm  ┆ first_adm  │
# │ ---      ┆ ---       ┆ ---        ┆ ---        ┆   ┆ ---   ┆ ---      ┆ ---         ┆ ---        │
# │ f64      ┆ f64       ┆ f64        ┆ date       ┆   ┆ f64   ┆ str      ┆ str         ┆ str        │
# ╞══════════╪═══════════╪════════════╪════════════╪═══╪═══════╪══════════╪═════════════╪════════════╡
# │ 0.451    ┆ 109.06416 ┆ 334.46     ┆ 2023-01-01 ┆ … ┆ 27.04 ┆ Day      ┆ Mempawah    ┆ Kalimantan │
# │          ┆           ┆            ┆            ┆   ┆       ┆          ┆             ┆ Barat      │
# │ -1.32986 ┆ 113.40453 ┆ 342.43     ┆ 2023-01-01 ┆ … ┆ 7.98  ┆ Day      ┆ Gunung Mas  ┆ Kalimantan │
# │          ┆           ┆            ┆            ┆   ┆       ┆          ┆             ┆ Tengah     │
# │ -0.84505 ┆ 116.93285 ┆ 341.42     ┆ 2023-01-01 ┆ … ┆ 9.12  ┆ Day      ┆ Kutai       ┆ Kalimantan │
# │          ┆           ┆            ┆            ┆   ┆       ┆          ┆ Kartanegara ┆ Timur      │
# │ -1.47823 ┆ 113.02875 ┆ 329.07     ┆ 2023-01-01 ┆ … ┆ 2.06  ┆ Day      ┆ Katingan    ┆ Kalimantan │
# │          ┆           ┆            ┆            ┆   ┆       ┆          ┆             ┆ Tengah     │
# │ …        ┆ …         ┆ …          ┆ …          ┆ … ┆ …     ┆ …        ┆ …           ┆ …          │
# │ 1.94859  ┆ 109.58205 ┆ 345.78     ┆ 2023-09-01 ┆ … ┆ 12.65 ┆ Day      ┆ null        ┆ null       │
# │ 1.95421  ┆ 109.58127 ┆ 331.72     ┆ 2023-09-01 ┆ … ┆ 12.65 ┆ Day      ┆ null        ┆ null       │
# │ 1.95475  ┆ 109.58498 ┆ 357.0      ┆ 2023-09-01 ┆ … ┆ 28.73 ┆ Day      ┆ null        ┆ null       │
# │ 1.61386  ┆ 109.24997 ┆ 367.0      ┆ 2023-09-01 ┆ … ┆ 32.63 ┆ Day      ┆ Sambas      ┆ Kalimantan │
# │          ┆           ┆            ┆            ┆   ┆       ┆          ┆             ┆ Barat      │
# └──────────┴───────────┴────────────┴────────────┴───┴───────┴──────────┴─────────────┴────────────┘
